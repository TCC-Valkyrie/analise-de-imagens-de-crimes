# %% [markdown]
# ### Importing the libraries

# %%
# Default imports
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

# Machine Learning
import torch
from ultralytics import YOLO
from torchvision import transforms
from sklearn.model_selection import train_test_split
# Out:
# Creating new Ultralytics Settings v0.0.6 file
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\davih\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %% [markdown]
# ### Tests

# %%
transform_pipeline = transforms.Compose([
    transforms.Resize((640, 640)),        # Resizing the image to 640x640 pixels (common input size for YOLO models)
    transforms.ToTensor(),                # Converts to a PyTorch Tensor AND scales pixels from 0-255 to 0.0-1.0
    transforms.Normalize(                 # Standardizes the colors (ImageNet standards used by most models)
        mean=[0.485, 0.456, 0.406], 
        std=[0.229, 0.224, 0.225]
    )
])

img_path = 'Robbery137_x264_1040.png'
image = Image.open(img_path).convert('RGB')

image_tensor = transform_pipeline(image)

input_batch = image_tensor.unsqueeze(0)
