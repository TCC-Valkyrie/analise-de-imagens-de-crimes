# %%
from ultralytics import YOLO

# 1. Load your trained model
model = YOLO("runs/detect/robbery_model/initial_training-2/weights/best.pt")

# 2. Run inference on a new image
results = model.predict(source="dataset/valid/images/burg10_0111_jpg.rf.7e94ddee540b7f3536c490e4f9edaab5.jpg", save=True, conf=0.3)

# 3. View the results
for r in results:
    r.show()
# Out:
# image 1/1 c:\Users\gabri\Desktop\analise-de-imagens-de-crimes\dataset\valid\images\burg10_0111_jpg.rf.7e94ddee540b7f3536c490e4f9edaab5.jpg: 640x640 1 burglary, 336.9ms
# Speed: 2.8ms preprocess, 336.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to C:\Users\gabri\Desktop\analise-de-imagens-de-crimes\runs\detect\predict-6
